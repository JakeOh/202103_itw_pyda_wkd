# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202103_itw_pyda_wkd/blob/main/da08_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 데이터 파일이 있는 URL 주소
file_path = 'https://github.com/JakeOh/202103_itw_pyda_wkd/raw/main/gapminder.tsv'

# %% [markdown]
# CSV(Comma-Separated Values) 파일:
# *   값들이 구분자(separator)로 구분되어서 저장된 텍스트 파일
# *   일반적으로 구분자는 쉼표(,)를 많이 사용
# *   구분자로 탭('\t'), 콜론(:) 등 다양하게 사용됨

# %%
# CSV 파일을 읽어서 데이터 프레임을 생성
gapminder = pd.read_csv(file_path, sep='\t')

# %%
type(gapminder)
# Out:
# pandas.core.frame.DataFrame

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.shape  # (n_rows, n_columns)
# Out:
# (1704, 6)

# %%
# 첫 n개의 행(row)을 선택
gapminder.head(n=6)  # n의 기본값은 5.
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360

# %%
# 마지막 n개의 행(row)을 선택
gapminder.tail()  # n의 기본값은 5.
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# 데이터 프레임의 컬럼 이름
gapminder.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gapminder.describe()  
#> 데이터 프레임에서 숫자형 데이터들의 기술 통계 요약 정보
#> NA가 아닌 원소 개수, 평균, 표준편차, 최솟값, 백분위값(25%, 50%, 75%), 최댓값
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
# DF 컬럼 선택: df[컬럼], df[[컬럼1, 컬럼2, ...]]
# gapminer 데이터 프레임에서 국가이름, 연도, 1인당GDP를 선택
gapminder[['country', 'year', 'gdpPercap']]
# Out:
#           country  year   gdpPercap
# 0     Afghanistan  1952  779.445314
# 1     Afghanistan  1957  820.853030
# 2     Afghanistan  1962  853.100710
# 3     Afghanistan  1967  836.197138
# 4     Afghanistan  1972  739.981106
# ...           ...   ...         ...
# 1699     Zimbabwe  1987  706.157306
# 1700     Zimbabwe  1992  693.420786
# 1701     Zimbabwe  1997  792.449960
# 1702     Zimbabwe  2002  672.038623
# 1703     Zimbabwe  2007  469.709298
#
# [1704 rows x 3 columns]

# %%
# DF row 선택: df.loc[], df.iloc[]
# gapminder 데이터 프레임에서 첫 5개 행을 선택
gapminder.loc[:4]
# gapminder.loc[0:4]도 같은 결과
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gapminder.iloc[:5]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# gapminder 데이터 프레임에서 끝에서 5개 row 선택
gapminder.iloc[-5:]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
gapminder.loc[1699:]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# row: 0 ~ 4, column: country, year, pop 선택
gapminder.loc[0:4, ['country', 'year', 'pop']]
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460

# %%
gapminder.iloc[0:5, [0, 2, 4]]
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460

# %%
gapminder.loc[0, 'country']
# Out:
# 'Afghanistan'

# %%
gapminder.iloc[0, 0]
# Out:
# 'Afghanistan'

# %% [markdown]
# 조건을 만족하는 행(row) 선택

# %%
# 2007년 자료만 출력
gapminder[gapminder['year'] == 2007]
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
# [142 rows x 6 columns]

# %%
# 2007년의 나라이름, 인구, 1인당GDP
gapminder_2007 = gapminder[gapminder['year'] == 2007]
gapminder_2007
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
# [142 rows x 6 columns]

# %%
gapminder_2007[['country', 'pop', 'gdpPercap']]
# Out:
#                  country       pop     gdpPercap
# 11           Afghanistan  31889923    974.580338
# 23               Albania   3600523   5937.029526
# 35               Algeria  33333216   6223.367465
# 47                Angola  12420476   4797.231267
# 59             Argentina  40301927  12779.379640
# ...                  ...       ...           ...
# 1655             Vietnam  85262356   2441.576404
# 1667  West Bank and Gaza   4018332   3025.349798
# 1679         Yemen, Rep.  22211743   2280.769906
# 1691              Zambia  11746035   1271.211593
# 1703            Zimbabwe  12311143    469.709298
#
# [142 rows x 3 columns]

# %%
gapminder[gapminder['year'] == 2007][['country', 'pop', 'gdpPercap']]
# select country, pop, gdpPercap from gapminder where year = 2007;
# Out:
#                  country       pop     gdpPercap
# 11           Afghanistan  31889923    974.580338
# 23               Albania   3600523   5937.029526
# 35               Algeria  33333216   6223.367465
# 47                Angola  12420476   4797.231267
# 59             Argentina  40301927  12779.379640
# ...                  ...       ...           ...
# 1655             Vietnam  85262356   2441.576404
# 1667  West Bank and Gaza   4018332   3025.349798
# 1679         Yemen, Rep.  22211743   2280.769906
# 1691              Zambia  11746035   1271.211593
# 1703            Zimbabwe  12311143    469.709298
#
# [142 rows x 3 columns]

# %%
# Zimbabwe의 자료들만 출력
gapminder[gapminder['country'] == 'Zimbabwe']
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1692  Zimbabwe    Africa  1952   48.451   3080907  406.884115
# 1693  Zimbabwe    Africa  1957   50.469   3646340  518.764268
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# 대한민국 자료: "Korea", "Republic of Korea", "Korea, Rep."
gapminder[gapminder['country'] == 'Korea, Rep.']
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 840  Korea, Rep.      Asia  1952   47.453  20947571   1030.592226
# 841  Korea, Rep.      Asia  1957   52.681  22611552   1487.593537
# 842  Korea, Rep.      Asia  1962   55.292  26420307   1536.344387
# 843  Korea, Rep.      Asia  1967   57.716  30131000   2029.228142
# 844  Korea, Rep.      Asia  1972   62.612  33505000   3030.876650
# 845  Korea, Rep.      Asia  1977   64.766  36436000   4657.221020
# 846  Korea, Rep.      Asia  1982   67.123  39326000   5622.942464
# 847  Korea, Rep.      Asia  1987   69.810  41622000   8533.088805
# 848  Korea, Rep.      Asia  1992   72.244  43805450  12104.278720
# 849  Korea, Rep.      Asia  1997   74.647  46173816  15993.527960
# 850  Korea, Rep.      Asia  2002   77.045  47969150  19233.988180
# 851  Korea, Rep.      Asia  2007   78.623  49044790  23348.139730

# %%
# 데이터 프레임에서 문자열이 저장된 컬럼을 다룰 때, 
# 문자열 함수들을 사용할 수 있음.
# str.contains('arg'): str이 'arg'를 포함하면 true, 그렇지 않으면 false
# str.startswith('arg'): str이 'arg'로 시작하면 true, 그렇지 않으면 false
# str.lower(): str을 모두 소문자로 변환
# str.upper(): str을 모두 대문자로 변환

gapminder[gapminder['country'].str.contains('Korea')]
# Out:
#               country continent  year  lifeExp       pop     gdpPercap
# 828  Korea, Dem. Rep.      Asia  1952   50.056   8865488   1088.277758
# 829  Korea, Dem. Rep.      Asia  1957   54.081   9411381   1571.134655
# 830  Korea, Dem. Rep.      Asia  1962   56.656  10917494   1621.693598
# 831  Korea, Dem. Rep.      Asia  1967   59.942  12617009   2143.540609
# 832  Korea, Dem. Rep.      Asia  1972   63.983  14781241   3701.621503
# 833  Korea, Dem. Rep.      Asia  1977   67.159  16325320   4106.301249
# 834  Korea, Dem. Rep.      Asia  1982   69.100  17647518   4106.525293
# 835  Korea, Dem. Rep.      Asia  1987   70.647  19067554   4106.492315
# 836  Korea, Dem. Rep.      Asia  1992   69.978  20711375   3726.063507
# 837  Korea, Dem. Rep.      Asia  1997   67.727  21585105   1690.756814
# 838  Korea, Dem. Rep.      Asia  2002   66.662  22215365   1646.758151
# 839  Korea, Dem. Rep.      Asia  2007   67.297  23301725   1593.065480
# ...

# %%
gapminder[gapminder['country'].str.lower().str.contains('korea')]
# Out:
#               country continent  year  lifeExp       pop     gdpPercap
# 828  Korea, Dem. Rep.      Asia  1952   50.056   8865488   1088.277758
# 829  Korea, Dem. Rep.      Asia  1957   54.081   9411381   1571.134655
# 830  Korea, Dem. Rep.      Asia  1962   56.656  10917494   1621.693598
# 831  Korea, Dem. Rep.      Asia  1967   59.942  12617009   2143.540609
# 832  Korea, Dem. Rep.      Asia  1972   63.983  14781241   3701.621503
# 833  Korea, Dem. Rep.      Asia  1977   67.159  16325320   4106.301249
# 834  Korea, Dem. Rep.      Asia  1982   69.100  17647518   4106.525293
# 835  Korea, Dem. Rep.      Asia  1987   70.647  19067554   4106.492315
# 836  Korea, Dem. Rep.      Asia  1992   69.978  20711375   3726.063507
# 837  Korea, Dem. Rep.      Asia  1997   67.727  21585105   1690.756814
# 838  Korea, Dem. Rep.      Asia  2002   66.662  22215365   1646.758151
# 839  Korea, Dem. Rep.      Asia  2007   67.297  23301725   1593.065480
# ...

# %%
# Asia, 2007년 자료 검색
gapminder[(gapminder['continent'] == 'Asia') & 
          (gapminder['year'] == 2007)]
# Out:
#                  country continent  year  lifeExp         pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828    31889923    974.580338
# 95               Bahrain      Asia  2007   75.635      708573  29796.048340
# 107           Bangladesh      Asia  2007   64.062   150448339   1391.253792
# 227             Cambodia      Asia  2007   59.723    14131858   1713.778686
# 299                China      Asia  2007   72.961  1318683096   4959.114854
# 671     Hong Kong, China      Asia  2007   82.208     6980412  39724.978670
# 707                India      Asia  2007   64.698  1110396331   2452.210407
# 719            Indonesia      Asia  2007   70.650   223547000   3540.651564
# 731                 Iran      Asia  2007   70.964    69453570  11605.714490
# 743                 Iraq      Asia  2007   59.545    27499638   4471.061906
# 767               Israel      Asia  2007   80.745     6426679  25523.277100
# ...

# %%
pd.options.display.max_rows = 10
# 콘솔 창에 출력되는 row 개수 최댓값을 10으로 제한.

# %%
# Asia 대륙의 2000년대 자료 검색
gapminder[(gapminder['continent'] == 'Asia') &
          (gapminder['year'] >= 2000)]
# Out:
#                  country continent  year  lifeExp        pop     gdpPercap
# 10           Afghanistan      Asia  2002   42.129   25268405    726.734055
# 11           Afghanistan      Asia  2007   43.828   31889923    974.580338
# 94               Bahrain      Asia  2002   74.795     656397  23403.559270
# 95               Bahrain      Asia  2007   75.635     708573  29796.048340
# 106           Bangladesh      Asia  2002   62.013  135656790   1136.390430
# ...                  ...       ...   ...      ...        ...           ...
# 1655             Vietnam      Asia  2007   74.249   85262356   2441.576404
# 1666  West Bank and Gaza      Asia  2002   72.370    3389578   4515.487575
# 1667  West Bank and Gaza      Asia  2007   73.422    4018332   3025.349798
# 1678         Yemen, Rep.      Asia  2002   60.308   18701257   2234.820827
# 1679         Yemen, Rep.      Asia  2007   62.698   22211743   2280.769906
#
# [66 rows x 6 columns]

# %%
# 1인당 GDP의 평균
gapminder['gdpPercap'].mean()

# 평균(mean), 표준편차(std), 최솟값(min), 최댓값(max), 중앙값(median), ...
# Out:
# 7215.327081212142

# %%
# 1인당 GDP가 최대인 레코드
gdp_max = gapminder['gdpPercap'].max()
gapminder[gapminder['gdpPercap'] == gdp_max]
# Out:
#     country continent  year  lifeExp     pop    gdpPercap
# 853  Kuwait      Asia  1957   58.033  212846  113523.1329

# %%
gapminder[gapminder['gdpPercap'] == gapminder['gdpPercap'].max()]
# Out:
#     country continent  year  lifeExp     pop    gdpPercap
# 853  Kuwait      Asia  1957   58.033  212846  113523.1329

# %%
# 1인당 GDP가 평균 이상인 레코드 검색
gdp_mean = gapminder['gdpPercap'].mean()
# print(gdp_mean)
gapminder[gapminder['gdpPercap'] >= gdp_mean]
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 51    Argentina  Americas  1967   65.634  22934225   8052.953021
# 52    Argentina  Americas  1972   67.065  24779799   9443.038526
# 53    Argentina  Americas  1977   68.481  26983828  10079.026740
# 54    Argentina  Americas  1982   69.942  29341374   8997.897412
# 55    Argentina  Americas  1987   70.774  31620918   9139.671389
# ...         ...       ...   ...      ...       ...           ...
# 1639  Venezuela  Americas  1987   70.190  17910182   9883.584648
# 1640  Venezuela  Americas  1992   71.150  20265563  10733.926310
# 1641  Venezuela  Americas  1997   72.146  22374398  10165.495180
# 1642  Venezuela  Americas  2002   72.766  24287670   8605.047831
# 1643  Venezuela  Americas  2007   73.747  26084662  11415.805690
#
# [534 rows x 6 columns]

# %%
# 2007년 자료 중에서 2007년의 1인당 GDP 평균 이상인 국가들의 자료.
gapminder_2007 = gapminder[gapminder['year'] == 2007]  # 2007년 자료
gdp_2007 = gapminder_2007['gdpPercap'].mean()  # 2007년 GDP 평균
gapminder_2007[gapminder_2007['gdpPercap'] >= gdp_2007]  # 평균 이상인 자료
# Out:
#                   country continent  year  lifeExp        pop    gdpPercap
# 59              Argentina  Americas  2007   75.320   40301927  12779.37964
# 71              Australia   Oceania  2007   81.235   20434176  34435.36744
# 83                Austria    Europe  2007   79.829    8199783  36126.49270
# 95                Bahrain      Asia  2007   75.635     708573  29796.04834
# 119               Belgium    Europe  2007   79.441   10392226  33692.60508
# ...                   ...       ...   ...      ...        ...          ...
# 1487          Switzerland    Europe  2007   81.701    7554661  37506.41907
# 1511               Taiwan      Asia  2007   78.400   23174294  28718.27684
# 1559  Trinidad and Tobago  Americas  2007   69.819    1056608  18008.50924
# 1607       United Kingdom    Europe  2007   79.425   60776238  33203.26128
# 1619        United States  Americas  2007   78.242  301139947  42951.65309
#
# [47 rows x 6 columns]

# %%
gapminder['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
# 2007년도 대륙별 1인당 GDP의 평균
for cont in gapminder_2007['continent'].unique():  # 대륙별로 반복
    # 각 대륙 부분집합을 찾고
    subset = gapminder_2007[gapminder_2007['continent'] == cont]
    # 각 대륙에서 GDP의 평균을 계산하고
    gdp_mean = subset['gdpPercap'].mean()
    print(cont, gdp_mean)  # 출력
# Out:
# Asia 12473.02687013333
# Europe 25054.481635933327
# Africa 3089.0326047365384
# Americas 11003.03162536
# Oceania 29810.188274999997

# %%
result = gapminder_2007.groupby('continent')['gdpPercap'].mean()
result
# Out:
# continent
# Africa       3089.032605
# Americas    11003.031625
# Asia        12473.026870
# Europe      25054.481636
# Oceania     29810.188275
# Name: gdpPercap, dtype: float64

# %%
plt.bar(x=result.index, height=result.values)
plt.show()

# %%
# gapminder 데이터프레임에서 연도별 1인당 GDP 평균
result = gapminder.groupby('year')['gdpPercap'].mean()
result
# Out:
# year
# 1952     3725.276046
# 1957     4299.408345
# 1962     4725.812342
# 1967     5483.653047
# 1972     6770.082815
#             ...
# 1987     7900.920218
# 1992     8158.608521
# 1997     9090.175363
# 2002     9917.848365
# 2007    11680.071820
# Name: gdpPercap, Length: 12, dtype: float64

# %%
plt.plot(result.index, result.values)
plt.show()

# %%
# 연도별 대륙별 1인당 GDP 평균
result = gapminder.groupby(['year', 'continent'])['gdpPercap'].mean()
result
# Out:
# year  continent
# 1952  Africa        1252.572466
#       Americas      4079.062552
#       Asia          5195.484004
#       Europe        5661.057435
#       Oceania      10298.085650
#                        ...
# 2007  Africa        3089.032605
#       Americas     11003.031625
#       Asia         12473.026870
#       Europe       25054.481636
#       Oceania      29810.188275
# Name: gdpPercap, Length: 60, dtype: float64

# %%
result = gapminder.groupby(['continent', 'year'])['gdpPercap'].mean()
result
# Out:
# continent  year
# Africa     1952     1252.572466
#            1957     1385.236062
#            1962     1598.078825
#            1967     2050.363801
#            1972     2339.615674
#                        ...
# Oceania    1987    20448.040160
#            1992    20894.045885
#            1997    24024.175170
#            2002    26938.778040
#            2007    29810.188275
# Name: gdpPercap, Length: 60, dtype: float64

# %%
result.unstack()
# unstack(): 2개 이상의 인덱스(multi-index)를 갖는 Seies에서 
# 가장 마지막 인덱스를 컬럼으로 변환한 DataFrame을 생성.
# unstack(level=n): n-th 레벨의 인덱스를 컬럼으로 변환.
# Out:
# year               1952          1957  ...          2002          2007
# continent                              ...
# Africa      1252.572466   1385.236062  ...   2599.385159   3089.032605
# Americas    4079.062552   4616.043733  ...   9287.677107  11003.031625
# Asia        5195.484004   5787.732940  ...  10174.090397  12473.026870
# Europe      5661.057435   6963.012816  ...  21711.732422  25054.481636
# Oceania    10298.085650  11598.522455  ...  26938.778040  29810.188275
#
# [5 rows x 12 columns]

# %%
result.unstack(level=1)
# Out:
# year               1952          1957  ...          2002          2007
# continent                              ...
# Africa      1252.572466   1385.236062  ...   2599.385159   3089.032605
# Americas    4079.062552   4616.043733  ...   9287.677107  11003.031625
# Asia        5195.484004   5787.732940  ...  10174.090397  12473.026870
# Europe      5661.057435   6963.012816  ...  21711.732422  25054.481636
# Oceania    10298.085650  11598.522455  ...  26938.778040  29810.188275
#
# [5 rows x 12 columns]

# %%
gdp_year_conti = result.unstack(level=0)
gdp_year_conti
# Out:
# continent       Africa      Americas          Asia        Europe       Oceania
# year
# 1952       1252.572466   4079.062552   5195.484004   5661.057435  10298.085650
# 1957       1385.236062   4616.043733   5787.732940   6963.012816  11598.522455
# 1962       1598.078825   4901.541870   5729.369625   8365.486814  12696.452430
# 1967       2050.363801   5668.253496   5971.173374  10143.823757  14495.021790
# 1972       2339.615674   6491.334139   8187.468699  12479.575246  16417.333380
# ...                ...           ...           ...           ...           ...
# 1987       2282.668991   7793.400261   7608.226508  17214.310727  20448.040160
# 1992       2281.810333   8044.934406   8639.690248  17061.568084  20894.045885
# 1997       2378.759555   8889.300863   9834.093295  19076.781802  24024.175170
# 2002       2599.385159   9287.677107  10174.090397  21711.732422  26938.778040
# 2007       3089.032605  11003.031625  12473.026870  25054.481636  29810.188275
#
# ...

# %%
plt.plot(gdp_year_conti['Africa'], label='Africa')
plt.plot(gdp_year_conti['Americas'], label='Americas')
plt.plot(gdp_year_conti['Asia'], label='Asia')
plt.plot(gdp_year_conti['Europe'], label='Europe')
plt.plot(gdp_year_conti['Oceania'], label='Oceania')

plt.legend()  # 범례(label) 표시
plt.show()

# %%
# 연도별 대륙별 1인당 GDP의 평균
gapminder.pivot_table(values='gdpPercap',
                      index='year',
                      columns='continent')
# pivot_table() 메서드의 파라미터:
# values: 집계 함수(aggreagting function)를 적용할 컬럼(들)
# index: groupby를 수행할 컬럼들 중에서 row에 표시할 컬럼이르(들)
# columns: groupby를 수행할 컬럼들 중에서 column에 표시할 컬럼이름(들)
# aggfunc: 집계 함수. 기본값은 평균(mean).
# Out:
# continent       Africa      Americas          Asia        Europe       Oceania
# year
# 1952       1252.572466   4079.062552   5195.484004   5661.057435  10298.085650
# 1957       1385.236062   4616.043733   5787.732940   6963.012816  11598.522455
# 1962       1598.078825   4901.541870   5729.369625   8365.486814  12696.452430
# 1967       2050.363801   5668.253496   5971.173374  10143.823757  14495.021790
# 1972       2339.615674   6491.334139   8187.468699  12479.575246  16417.333380
# ...                ...           ...           ...           ...           ...
# 1987       2282.668991   7793.400261   7608.226508  17214.310727  20448.040160
# 1992       2281.810333   8044.934406   8639.690248  17061.568084  20894.045885
# 1997       2378.759555   8889.300863   9834.093295  19076.781802  24024.175170
# 2002       2599.385159   9287.677107  10174.090397  21711.732422  26938.778040
# 2007       3089.032605  11003.031625  12473.026870  25054.481636  29810.188275
#
# ...

# %%
# 연도별 대륙별 인구수
df = gapminder.groupby(['year', 'continent'])['pop'].sum()
df
# Out:
# year  continent
# 1952  Africa        237640501
#       Americas      345152446
#       Asia         1395357351
#       Europe        418120846
#       Oceania        10686006
#                       ...
# 2007  Africa        929539692
#       Americas      898871184
#       Asia         3811953827
#       Europe        586098529
#       Oceania        24549947
# Name: pop, Length: 60, dtype: int64

# %%
df_unstack = df.unstack()
df_unstack
# Out:
# continent     Africa   Americas        Asia     Europe   Oceania
# year
# 1952       237640501  345152446  1395357351  418120846  10686006
# 1957       264837738  386953916  1562780599  437890351  11941976
# 1962       296516865  433270254  1696357182  460355155  13283518
# 1967       335289489  480746623  1905662900  481178958  14600414
# 1972       379879541  529384210  2150972248  500635059  16106100
# ...              ...        ...         ...        ...       ...
# 1987       574834110  682753971  2871220762  543094160  19574415
# 1992       659081517  739274104  3133292191  558142797  20919651
# 1997       743832984  796900410  3383285500  568944148  22241430
# 2002       833723916  849772762  3601802203  578223869  23454829
# 2007       929539692  898871184  3811953827  586098529  24549947
#
# [12 rows x 5 columns]

# %%
gapminder.pivot_table(values='pop',
                      index='year',
                      columns='continent',
                      aggfunc='sum')
# Out:
# continent     Africa   Americas        Asia     Europe   Oceania
# year
# 1952       237640501  345152446  1395357351  418120846  10686006
# 1957       264837738  386953916  1562780599  437890351  11941976
# 1962       296516865  433270254  1696357182  460355155  13283518
# 1967       335289489  480746623  1905662900  481178958  14600414
# 1972       379879541  529384210  2150972248  500635059  16106100
# ...              ...        ...         ...        ...       ...
# 1987       574834110  682753971  2871220762  543094160  19574415
# 1992       659081517  739274104  3133292191  558142797  20919651
# 1997       743832984  796900410  3383285500  568944148  22241430
# 2002       833723916  849772762  3601802203  578223869  23454829
# 2007       929539692  898871184  3811953827  586098529  24549947
#
# [12 rows x 5 columns]
